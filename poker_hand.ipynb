# %%
def straight_flush(value,suit):
    listx=['2','3','4','5','6','7','8','9','T','J','Q','K','A']
    consec=[]
    for i in range(0,9):
        listp=[]
        for j in range(0,5):
            listp.append(listx[i+j])
        consec.append(set(listp))
    value=set(value)
    if value in consec and len(set(suit))==1:
        return True
    else:
        return False
    
def royal_flush(value,suit):
    suit=set(suit)
    if len(suit)==1:
        value=set(value)
        if value=={'T','J','Q','K','A'}:
            return True
    
    return False

def  flush(value,suit):
    suit=set(suit)
    if len(suit)==1:
        return True
    else:
        return False
def four_of_kind(value,suit):
    for i in value:
        if value.count(i)==4:
            return True 
    return False 

def straight(value,suit):
    listx=['2','3','4','5','6','7','8','9','T','J','Q','K','A']
    consec=[]
    for i in range(0,9):
        listp=[]
        for j in range(0,5):
            listp.append(listx[i+j])
        consec.append(set(listp))
    value=set(value)
    if value in consec:
        return True
    else:
        return False
    
    
def three_of_kind(value,suit):
    for i in value:
        if value.count(i)==3:
            return True
    return False

def full_house(value,suit):
    count=0 
    
    for i in value:
        if value.count(i)==3:
            count=3
            
    value=set(value)
    if len(value)==2 and count==3:
        return True
    else:
        return False

def one_pair(value,suit):
    for i in value:
        if value.count(i)==2:
            return True
    return False

def two_pair(value,suit):
    temp=set(value)
    
    for i in temp:
        if value.count(i)==2 :
            temp=temp-{i}
            for j in temp:
                if value.count(j)==2:
                    return True
                
    return False

def highest_card(value,suit):
    temp=[]
    
    for i in value:
        
        if i=='A':
            temp.append(14)
        elif i=='K':
            temp.append(13)
        elif i=='Q':
            temp.append(12)
        elif i=='J':
            temp.append(11)
        elif i=='T':
            temp.append(10)
        else:
            temp.append(int(i))
        
    return int(max(temp))

# %%
win1=0
win2=0
tie=0
k=1
f=open("poker.txt","r")
for str1 in f:
   
    player1=str1[0:14]
    player2=str1[15:29]
    list1=player1.split(" ")
    list2=player2.split(" ")
    value1=[]
    suit1=[]
    value2=[]
    suit2=[]
    for i in list1:
        value1.append(i[0])
        suit1.append(i[1])
        
    for i in list2:
        value2.append(i[0])
        suit2.append(i[1])
    print(value1,suit1,value2,suit2,k)
    k=k+1
        
    
    if royal_flush(value1,suit1)==True and royal_flush(value2,suit2)==False:
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 royal flush")
    elif royal_flush(value2,suit2)==True and royal_flush(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 royal flush")
    elif royal_flush(value2,suit2)==True and royal_flush(value1,suit1)==True:
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    elif straight_flush(value1,suit1)==True and straight_flush(value2,suit2)==False:
        win1+win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 straight flush")
    elif straight_flush(value2,suit2)==True and straight_flush(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 straight flush")
    elif straight_flush(value2,suit2)==True and straight_flush(value1,suit1)==True:
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    elif four_of_kind(value1,suit1)==True and four_of_kind(value2,suit2)==False:
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 four of kind")
    elif four_of_kind(value2,suit2)==True and four_of_kind(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 four of kind")
    elif four_of_kind(value2,suit2)==True and four_of_kind(value1,suit1)==True:
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    elif full_house(value1,suit1)==True and full_house(value2,suit2)==False:
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 full house")
    elif full_house(value2,suit2)==True and full_house(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 full house")
    elif full_house(value2,suit2)==True and full_house(value1,suit1)==True:
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    elif flush(value1,suit1)==True and flush(value2,suit2)==False:
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 flush")
    elif flush(value2,suit2)==True and flush(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 flush")
    elif flush(value2,suit2)==True and flush(value1,suit1)==True:
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    elif straight(value1,suit1)==True and straight(value2,suit2)==False:
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 straight ")
    elif straight(value2,suit2)==True and straight(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 straight")
    elif straight(value2,suit2)==True and straight(value1,suit1)==True:
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    elif three_of_kind(value1,suit1)==True and three_of_kind(value2,suit2)==False:
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 three of kind")
    elif three_of_kind(value2,suit2)==True and three_of_kind(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 three of kind")
    elif three_of_kind(value2,suit2)==True and three_of_kind(value1,suit1)==True:
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    elif two_pair(value1,suit1)==True and two_pair(value2,suit2)==False:
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 two pair")
    elif two_pair(value2,suit2)==True and two_pair(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 two pairs")
    elif two_pair(value2,suit2)==True and two_pair(value1,suit1)==True:
            temp1=set(value1)
            temp2=set(value2)
            L1=[]
            L2=[]
            for i in temp1:
                if value1.count(i)==2 :
                    L1.append(i)
                    temp1=temp1-{i}
                    for j in temp1:
                        if value1.count(j)==2:
                            L1.append(j)
            for i in temp2:
                if value2.count(i)==2 :
                    L2.append(i)
                    temp2=temp2-{i}
                    for j in temp2:
                        if value2.count(j)==2:
                            L2.append(j) 
            if max(L1)>max(L2):
                win1=win1+1
            else:
                win2=win2+1
        
    elif one_pair(value1,suit1)==True and one_pair(value2,suit2)==False:
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 one pair")
    elif one_pair(value2,suit2)==True and one_pair(value1,suit1)==False:
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 one pair")
    elif one_pair(value2,suit2)==True and one_pair(value1,suit1)==True:
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    elif highest_card(value1,suit1)>highest_card(value2,suit2):
        win1=win1+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("1 higest card")
    elif highest_card(value2,suit2)>highest_card(value1,suit1):
        win2=win2+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("2 higest card")
    elif highest_card(value2,suit2)==hightest_card(value1,suit1):
        tie=tie+1
        print(value1,suit1,end="  ")
        print(value2,suit2,end="  ")
        print("tie")
    
    
    
print("player 1 won",win1)
print("player 2 won",win2)       
        
print("tie ",tie)
# Out:
# ['8', 'T', 'K', '9', '4'] ['C', 'S', 'C', 'H', 'S'] ['7', '2', '5', '3', 'A'] ['D', 'S', 'D', 'S', 'C'] 1
# ['8', 'T', 'K', '9', '4'] ['C', 'S', 'C', 'H', 'S']  ['7', '2', '5', '3', 'A'] ['D', 'S', 'D', 'S', 'C']  2 higest card
# ['5', 'A', '5', 'A', '9'] ['C', 'D', 'D', 'C', 'C'] ['7', '5', '8', 'T', 'K'] ['C', 'H', 'D', 'D', 'S'] 2
# ['5', 'A', '5', 'A', '9'] ['C', 'D', 'D', 'C', 'C']  ['7', '5', '8', 'T', 'K'] ['C', 'H', 'D', 'D', 'S']  1 two pair
# ['3', '7', '6', 'K', 'J'] ['H', 'H', 'S', 'C', 'S'] ['Q', 'T', 'J', '2', '8'] ['H', 'D', 'C', 'D', 'S'] 3
# ['3', '7', '6', 'K', 'J'] ['H', 'H', 'S', 'C', 'S']  ['Q', 'T', 'J', '2', '8'] ['H', 'D', 'C', 'D', 'S']  1 higest card
# ['T', '8', '5', 'Q', 'T'] ['H', 'H', 'C', 'S', 'C'] ['9', '4', 'J', 'K', 'J'] ['H', 'D', 'C', 'S', 'S'] 4
# ['T', '8', '5', 'Q', 'T'] ['H', 'H', 'C', 'S', 'C']  ['9', '4', 'J', 'K', 'J'] ['H', 'D', 'C', 'S', 'S']  tie
# ...

# %%
    
value=['A','T','K','Q','J']
suit=['S','S','S','S','S']
print(royal_flush(value,suit))
# Out:
# True

# %%
suit1
# Out:
# ['S', 'D', 'D', 'D', 'H']

# %%
vallue={'A','B','C'}
vallue
