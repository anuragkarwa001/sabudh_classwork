# %%
n=int(input("enter the number "))
k=1
if n%2==0:
    print("pattern not possible")
else:
    l=(n+1)//2
for i in range(0,l):
    for j in range(0,l-i-1):
        print(" ",end="")
   
    for x in range(0,k):
        print("$",end="")
    for z in range(0,l-i-1):
        print(" ",end="")
    print("")
    k=k+2
k=k-2
for i in range(0,l-1):
    for p in range(0,i+1):
        print(" ",end="")
    k=k-2
    for q in range(0,k):
        print("$",end="")
    for p in range(0,i+1):
        print("",end="")
    print()
# Out:
# enter the number 67
#                                  $
#                                 $$$
#                                $$$$$
#                               $$$$$$$
#                              $$$$$$$$$
#                             $$$$$$$$$$$
#                            $$$$$$$$$$$$$
#                           $$$$$$$$$$$$$$$
#                          $$$$$$$$$$$$$$$$$
#                         $$$$$$$$$$$$$$$$$$$
#                        $$$$$$$$$$$$$$$$$$$$$
#                       $$$$$$$$$$$$$$$$$$$$$$$
#                      $$$$$$$$$$$$$$$$$$$$$$$$$
#                     $$$$$$$$$$$$$$$$$$$$$$$$$$$
#                    $$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#                   $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#                  $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#                 $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#                $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#               $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ...
